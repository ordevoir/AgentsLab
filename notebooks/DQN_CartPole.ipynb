# %% [markdown]
# # DQN on CartPole (TorchRL)

# %%
from agentslab.envs.gymnasium import make_gym_env
from agentslab.models.networks import make_mlp
from agentslab.runner.train import train_dqn, DQNConfig
from agentslab.utils.device import select_device
from agentslab.utils.seeding import seed_everything

device = select_device('cuda')
seed_everything(0)
env_id = 'CartPole-v1'
def create_env():
    return make_gym_env(env_id, device=device)
env = create_env()
obs_dim = env.observation_spec['observation'].shape[-1]
act_dim = env.action_spec.shape[-1]
q_net = make_mlp(obs_dim, act_dim, num_cells=64, depth=2, device=device)
run = train_dqn(create_env, q_net, env.action_spec, device, log_dir='../logs', ckpt_dir='../checkpoints', env_name=env_id, seed=0, cfg=DQNConfig())
print('Run:', run)
# Out:
# 2025-08-18 14:14:33,530 INFO loss=1.0869 @ 0
# 2025-08-18 14:14:33,572 INFO loss=1.1067 @ 1
# 2025-08-18 14:14:33,621 INFO loss=1.0864 @ 2
# 2025-08-18 14:14:33,666 INFO loss=0.9792 @ 3
# 2025-08-18 14:14:33,707 INFO loss=0.9926 @ 4
# 2025-08-18 14:14:33,750 INFO loss=0.9251 @ 5
# 2025-08-18 14:14:33,792 INFO loss=0.9827 @ 6
# 2025-08-18 14:14:33,834 INFO loss=0.9164 @ 7
# 2025-08-18 14:14:33,874 INFO loss=0.8621 @ 8
# 2025-08-18 14:14:33,919 INFO loss=0.8330 @ 9
# 2025-08-18 14:14:33,963 INFO loss=0.8046 @ 10
# 2025-08-18 14:14:34,005 INFO loss=0.7410 @ 11
# 2025-08-18 14:14:34,047 INFO loss=0.7205 @ 12
# 2025-08-18 14:14:34,092 INFO loss=0.7000 @ 13
# 2025-08-18 14:14:34,160 INFO loss=0.6205 @ 14
# 2025-08-18 14:14:34,216 INFO loss=0.6575 @ 15
# 2025-08-18 14:14:34,260 INFO loss=0.6005 @ 16
# 2025-08-18 14:14:34,302 INFO loss=0.5263 @ 17
# 2025-08-18 14:14:34,346 INFO loss=0.5391 @ 18
# 2025-08-18 14:14:34,387 INFO loss=0.5152 @ 19
# 2025-08-18 14:14:34,428 INFO loss=0.4436 @ 20
# ...
